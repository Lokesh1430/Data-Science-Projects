# %% [markdown]
# <h3><center><b><i>Exploring Superstore Data: A Statistical Analysis and Visualization of Sales, Profit, and Ship Mode Insights</b></i></center></h3>

# %% [markdown]
# ### **===========================================================================================================**

# %% [markdown]
# **Exploring Superstore Data: A Statistical Analysis and Visualization of Sales, Profit, and Ship Mode Insights**
# ================================================
#
# ### Overview
#
# In this project, we will explore the Superstore dataset, analyzing sales, profit, and ship mode insights. We will use statistical methods to identify trends and patterns, and then visualize the findings using various data visualization techniques.
#
# ### References
#
# * [1] **Superstore Dataset**: The Superstore dataset is a publicly available dataset that contains information about sales, profit, and ship mode for a fictional retail store. [Available at](https://community.tableau.com/s/contentdocument/0694T000001GnpUQAS).
# * [2] **Python**: The Python programming language was used to perform the data analysis and visualization in this project. [Available at](https://www.python.org/).
# * [3] **Pandas**: The Pandas library was used to manipulate and analyze the data in this project. [Available at](https://pandas.pydata.org/).
# * [4] **Matplotlib**: The Matplotlib library was used to create visualizations in this project. [Available at](https://matplotlib.org/).
#
# ### Libraries
#
# * **Python**: Python 3.9 or higher
# * **Pandas**: Pandas 1.3.5 or higher
# * **Matplotlib**: Matplotlib 3.5.0 or higher
# * **Seaborn**: Seaborn 0.11.2 or higher (optional)
#
# ### Methods
#
# * Data cleaning and preprocessing
# * Statistical analysis (descriptive statistics, correlation analysis, etc.)
# * Data visualization (scatter plots, bar charts, histograms, etc.)
#
# ### Results
#
# * [Code Is Displayed On Bellow]
#
# ### Conclusion
#
# This project aims to provide a comprehensive analysis of the Superstore dataset, highlighting key insights into sales, profit, and ship mode. The results will be used to inform business decisions and improve the overall performance of the Superstore.

# %% [markdown]
# ### **===========================================================================================================**

# %% [markdown]
# ### Importing the necessary libraries and loading the data

# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_excel("C:\\Users\\lokesh\\Downloads\\Sample - Superstore.xls")

# %% [markdown]
# ### How Many Rows And Columns In The DataSet

# %%
df.shape
# Out:
# (9994, 21)

# %% [markdown]
# ### To Select The Top 10 Columns And Rows

# %%
df.head(10)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7       8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8       9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9      10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %% [markdown]
# ### To Select The  Bellow 10 Columns And Rows

# %%
df.tail(10)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9984    9985  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985    9986  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9986    9987  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9987    9988  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988    9989  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country         City  \
# 9984    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# 9985    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# ...

# %% [markdown]
# ### DataFrame Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9991 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# ### Checking for Null Values in the DataFrame

# %%
pd.isnull(df)
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
# ...      ...       ...         ...        ...        ...          ...
# 9989   False     False       False      False      False        False
# 9990   False     False       False      False      False        False
# 9991   False     False       False      False      False        False
# 9992   False     False       False      False      False        False
# 9993   False     False       False      False      False        False
#
#       Customer Name  Segment  Country   City  ...  Postal Code  Region  \
# ...

# %% [markdown]
# ### Checking for Non-Null Values in the DataFrame

# %%
pd.notnull(df)
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0       True      True        True       True       True         True
# 1       True      True        True       True       True         True
# 2       True      True        True       True       True         True
# 3       True      True        True       True       True         True
# 4       True      True        True       True       True         True
# ...      ...       ...         ...        ...        ...          ...
# 9989    True      True        True       True       True         True
# 9990    True      True        True       True       True         True
# 9991    True      True        True       True       True         True
# 9992    True      True        True       True       True         True
# 9993    True      True        True       True       True         True
#
#       Customer Name  Segment  Country  City  ...  Postal Code  Region  \
# ...

# %% [markdown]
# ### Counting the Number of Null Values in the DataFrame

# %%
pd.isnull(df).sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          3
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# ### Counting the Number of Rows with at Least One Null Value

# %%
df.isnull().any(axis=1).sum()
# Out:
# 3

# %% [markdown]
# ### Filtering Rows with at Least One Null Value

# %%
df[df.isnull().any(axis=1)]
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0        1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 7        8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 21      22  CA-2016-137330 2016-12-09 2016-12-13  Standard Class    KB-16585
#
#       Customer Name    Segment Country         City  ... Postal Code   Region  \
# 0       Claire Gute   Consumer     NaN    Henderson  ...       42420    South
# 7   Brosina Hoffman   Consumer     NaN  Los Angeles  ...       90032     West
# 21        Ken Black  Corporate     NaN      Fremont  ...       68025  Central
#
#          Product ID         Category Sub-Category  \
# 0   FUR-BO-10001798        Furniture    Bookcases
# 7   TEC-PH-10002275       Technology       Phones
# 21  OFF-AR-10000246  Office Supplies          Art
#
#                          Product Name    Sales  Quantity  Discount   Profit
# ...

# %% [markdown]
# ### Counting Non-Null Values in the DataFrame

# %%
pd.notnull(df).sum()
# Out:
# Row ID           9994
# Order ID         9994
# Order Date       9994
# Ship Date        9994
# Ship Mode        9994
# Customer ID      9994
# Customer Name    9994
# Segment          9994
# Country          9991
# City             9994
# State            9994
# Postal Code      9994
# Region           9994
# Product ID       9994
# Category         9994
# Sub-Category     9994
# Product Name     9994
# Sales            9994
# Quantity         9994
# Discount         9994
# Profit           9994
# dtype: int64

# %% [markdown]
# ### Replacing Null Values with NaN

# %%
df=df.fillna(np.NAN)
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer            NaN        Henderson
# ...

# %% [markdown]
# ### Counting NaN Values in the DataFrame

# %%
pd.isnull(df).sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          3
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# ### Selecting Rows with NaN Values

# %%
nan_rows=df[df.isna().any(axis=1)]
nan_rows
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0        1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 7        8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 21      22  CA-2016-137330 2016-12-09 2016-12-13  Standard Class    KB-16585
#
#       Customer Name    Segment Country         City  ... Postal Code   Region  \
# 0       Claire Gute   Consumer     NaN    Henderson  ...       42420    South
# 7   Brosina Hoffman   Consumer     NaN  Los Angeles  ...       90032     West
# 21        Ken Black  Corporate     NaN      Fremont  ...       68025  Central
#
#          Product ID         Category Sub-Category  \
# 0   FUR-BO-10001798        Furniture    Bookcases
# 7   TEC-PH-10002275       Technology       Phones
# 21  OFF-AR-10000246  Office Supplies          Art
#
#                          Product Name    Sales  Quantity  Discount   Profit
# ...

# %% [markdown]
# ### Forward Filling Missing Values

# %%
df.ffill(inplace=True)
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 5          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# ### Counting Unique Values in Each Column

# %%
df.nunique()
# Out:
# Row ID           9994
# Order ID         5009
# Order Date       1237
# Ship Date        1334
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              531
# State              49
# Postal Code       631
# Region              4
# Product ID       1862
# Category            3
# Sub-Category       17
# Product Name     1850
# Sales            6144
# Quantity           14
# Discount           12
# Profit           7545
# dtype: int64

# %% [markdown]
# ### Extracting Unique Values from Multiple Columns

# %%
unique_names = df[['Ship Mode', 'Segment', 'Region', 'Category']].values.ravel()
unique_names = list(set(unique_names))
print(unique_names)
# Out:
# ['First Class', 'East', 'Standard Class', 'Same Day', 'Home Office', 'Consumer', 'Technology', 'Central', 'Office Supplies', 'Furniture', 'Second Class', 'Corporate', 'West', 'South']

# %% [markdown]
# ### Removing Rows with Missing Values

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### Accessing Column Labels

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ### Generating Summary Statistics

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  9993.000000                           9993
# mean   4998.000000  2016-04-29 23:39:32.260582144
# min       2.000000            2014-01-03 00:00:00
# 25%    2500.000000            2015-05-23 00:00:00
# 50%    4998.000000            2016-06-26 00:00:00
# 75%    7496.000000            2017-05-14 00:00:00
# max    9994.000000            2017-12-30 00:00:00
# std    2884.874954                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9993   9993.000000   9993.000000  9993.000000
# mean   2016-05-03 22:39:26.856799744  55191.657360    229.854788     3.789753
# min              2014-01-07 00:00:00   1040.000000      0.444000     1.000000
# 25%              2015-05-27 00:00:00  23223.000000     17.280000     2.000000
# 50%              2016-06-29 00:00:00  56560.000000     54.480000     3.000000
# ...

# %% [markdown]
# ### Generating Summary Statistics with Custom Percentiles

# %%
df.describe(percentiles=[0.01,0.99,0.50,0.25,0.75])
# Out:
#             Row ID                     Order Date  \
# count  9993.000000                           9993
# mean   4998.000000  2016-04-29 23:39:32.260582144
# min       2.000000            2014-01-03 00:00:00
# 1%      101.920000            2014-02-11 00:00:00
# 25%    2500.000000            2015-05-23 00:00:00
# 50%    4998.000000            2016-06-26 00:00:00
# 75%    7496.000000            2017-05-14 00:00:00
# 99%    9894.080000            2017-12-22 00:00:00
# max    9994.000000            2017-12-30 00:00:00
# std    2884.874954                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9993   9993.000000   9993.000000  9993.000000
# mean   2016-05-03 22:39:26.856799744  55191.657360    229.854788     3.789753
# min              2014-01-07 00:00:00   1040.000000      0.444000     1.000000
# 1%               2014-02-15 00:00:00   2149.000000      2.286000     1.000000
# ...

# %% [markdown]
# ### Generating Summary Statistics for a Specific Column

# %%
df['Sales'].describe()
# Out:
# count     9993.000000
# mean       229.854788
# std        623.276204
# min          0.444000
# 25%         17.280000
# 50%         54.480000
# 75%        209.940000
# max      22638.480000
# Name: Sales, dtype: float64

# %% [markdown]
# ### Creating a Line Plot to Visualize Sales

# %%
# Create a visualization for sales
plt.figure(figsize=(12, 6))
plt.plot(df['Sales'])
plt.title('Sales Over Time')
plt.xlabel('Index')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Scatter Plot for Sales vs. Profit

# %%
# Create a scatter plot for Sales vs. Profit
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Sales', y='Profit', data=df)
plt.title('Sales vs. Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Bar Plot for Ship Mode

# %%
# Create a bar plot for Ship Mode
plt.figure(figsize=(8, 5))
sns.countplot(x='Ship Mode', data=df)
plt.title('Ship Mode Distribution')
plt.xlabel('Ship Mode')
plt.ylabel('Count')
plt.show()
